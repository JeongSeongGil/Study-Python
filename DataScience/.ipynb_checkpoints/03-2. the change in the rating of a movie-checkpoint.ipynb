# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20200330"
page = urlopen(url)

soup = BeautifulSoup(page, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20200330" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=181710" title="포드 V 페라리">포드 V 페라리</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=19099" title="트루먼 쇼">트루먼 쇼</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=31013" title="빌리 엘리어트">빌리 엘리어트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=47152" title="테이큰">테이큰</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=148338" title="동급생">동급생</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=187308" title="조조 래빗">조조 래빗</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=168050" title="스타 이즈 본">스타 이즈 본</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=92075" title="어바웃 타임">어바웃 타임</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=158578" title="흑집사 : 북 오브 더 아틀란틱">흑집사 : 북 오브 더 아틀란틱</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '포드 V 페라리'

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.50'

# %%
len(soup.find_all('td', 'point'))
# Out:
# 50

# %%
date = pd.date_range('2020-1-5', periods = 100, freq ="D")

date
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17',
#                '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21',
#                '2020-02-22', '2020-02-23', '2020-02-24', '2020-02-25',
# ...

# %%
movie_name = [soup.find_all('div', 'tit5')[n].a.string for n in range(0, 50)]
movie_name
# Out:
# ['포드 V 페라리',
#  '트루먼 쇼',
#  '빌리 엘리어트',
#  '테이큰',
#  '동급생',
#  '조조 래빗',
#  '스타 이즈 본',
#  '어바웃 타임',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나이브스 아웃',
#  '히트',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '노팅 힐',
#  '샤인',
#  '결혼 이야기',
#  '타오르는 여인의 초상',
#  '비긴 어게인',
#  '1917',
#  '스포트라이트',
#  '파이트 클럽',
#  '슬럼독 밀리어네어',
#  '작은 아씨들',
#  '아이리시맨',
#  '벌새',
#  '부르고뉴, 와인에서 찾은 인생',
#  '브리짓 존스의 일기',
#  '세븐',
#  '다크 워터스',
#  '라라랜드',
#  '내일을 위한 시간',
#  '졸업',
#  '울프 콜',
#  '미드나잇 인 파리',
#  '그녀',
#  '더 와이프',
#  '러브 라이브! 더 스쿨 아이돌 무비',
#  '신비아파트 극장판 하늘도깨비 대 요르문간드',
#  '극한직업',
#  '기생충',
#  '스틸 앨리스',
#  '아무르',
#  '500일의 썸머',
#  '레토',
#  '그랜드 부다페스트 호텔',
#  '레미제라블',
#  '러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우',
#  '케빈에 대하여',
#  '유스',
#  '젠틀맨',
#  '우리도 사랑일까']

# %%
movie_point = [soup.find_all('td', 'point')[n].string for n in range(0, 50)]

movie_point
# Out:
# ['9.50',
#  '9.33',
#  '9.31',
#  '9.21',
#  '9.20',
#  '9.18',
#  '9.17',
#  '9.16',
#  '9.15',
#  '9.11',
#  '9.09',
#  '9.09',
#  '9.08',
#  '9.08',
#  '9.07',
#  '9.04',
#  '9.02',
#  '8.94',
#  '8.93',
#  '8.88',
#  '8.83',
#  '8.82',
#  '8.79',
#  '8.76',
#  '8.69',
#  '8.67',
#  '8.66',
#  '8.61',
#  '8.60',
#  '8.55',
#  '8.54',
#  '8.53',
#  '8.52',
#  '8.52',
#  '8.51',
#  '8.51',
#  '8.50',
#  '8.50',
#  '8.49',
#  '8.46',
#  '8.45',
#  '8.41',
#  '8.40',
#  '8.38',
#  '8.37',
#  '8.37',
#  '8.37',
#  '8.30',
#  '8.29',
#  '8.28']

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# A Jupyter Widget

# %%
len(movie_name), len(movie_date), len(movie_point)
# Out:
# (4631, 4631, 4631)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 
                                      'point':movie_point})
movie.head()
# Out:
#         date      name point
# 0 2020-01-05  포드 V 페라리  9.55
# 1 2020-01-05       주전장  9.53
# 2 2020-01-05      두 교황  9.34
# 3 2020-01-05      러브 앳  9.27
# 4 2020-01-05      교회오빠  9.27

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4631 entries, 0 to 4630
# Data columns (total 3 columns):
# date     4631 non-null datetime64[ns]
# name     4631 non-null object
# point    4631 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 108.6+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4631 entries, 0 to 4630
# Data columns (total 3 columns):
# date     4631 non-null datetime64[ns]
# name     4631 non-null object
# point    4631 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 108.6+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index =['name'], aggfunc = np.sum)
movie_best = movie_unique.sort_values(by = 'point', ascending=False)
movie_best.head()
# Out:
#            point
# name
# 나이브스 아웃   912.11
# 벌새        881.67
# 기생충       823.68
# 포드 V 페라리  818.59
# 두 교황      794.06

# %%
tmp = movie.query('name == ["기생충"]')
tmp.head()
# Out:
#           date name  point
# 22  2020-01-05  기생충   8.49
# 59  2020-01-06  기생충   8.49
# 98  2020-01-07  기생충   8.49
# 139 2020-01-08  기생충   8.49
# 179 2020-01-09  기생충   8.49

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
movie_best.head()
# Out:
#            point
# name
# 나이브스 아웃   912.11
# 벌새        881.67
# 기생충       823.68
# 포드 V 페라리  818.59
# 두 교황      794.06

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], 
                                         values=['point'])
movie_pivot.head()
# Out:
#            point                                                             \
# name        1917 21 브릿지: 테러 셧다운 500일의 썸머 82년생 김지영 가장 따뜻한 색, 블루 걸어도 걸어도 겟 아웃
# date
# 2020-01-05   NaN            NaN      NaN     6.69          NaN     NaN  NaN
# 2020-01-06   NaN            NaN      NaN     6.69          NaN     NaN  NaN
# 2020-01-07   NaN            NaN      NaN     6.69          NaN     NaN  NaN
# 2020-01-08   NaN           8.02      NaN     6.69          NaN     NaN  NaN
# 2020-01-09   NaN           8.02      NaN     6.69          NaN     NaN  NaN
#
#                                      ...                           \
# name       겨울왕국 2 결혼 이야기 고양이를 빌려드립니다 ... 하이큐!! 끝과 시작 하이큐!! 승자와 패자
# date                                 ...
# 2020-01-05   8.71   9.07         NaN ...         NaN          NaN
# 2020-01-06   8.71   9.07         NaN ...         NaN          NaN
# 2020-01-07   8.71   9.07         NaN ...        8.91          9.0
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
target_col = ['포드 V 페라리', '기생충', '극한직업', '라라랜드']
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -pencv-python                      4.5.1.48
# absl-py                            0.12.0
# alabaster                          0.7.12
# altair                             4.1.0
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arviz                              0.11.2
# asn1crypto                         1.4.0
# astor                              0.8.1
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# ...
